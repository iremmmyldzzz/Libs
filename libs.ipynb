# %%
import numpy as np

a = np.array([1, 2, 3])
print("Ortalama:", np.mean(a))
# Out:
# Ortalama: 2.0

# %%
import pandas as pd

df = pd.read_csv("veri.csv")
print(df.head())
print("Eksik değerler:", df.isnull().sum())
# Out:
#      isim  yas
# 0   Ahmet   25
# 1    Ayşe   32
# 2  Mehmet   45
# 3   Fatma   28
# 4    Elif   35
# Eksik değerler: isim    0
# yas     0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Basit Çizgi Grafiği")
plt.xlabel("X Ekseni")
plt.ylabel("Y Ekseni")
plt.show()

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

X = [[1], [2], [3], [4]]
y = [2, 4, 6, 8]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("R2 Skoru:", r2_score(y_test, y_pred))
# Out:
# R2 Skoru: 1.0

# %%
from scipy import stats

a = [2.4, 2.5, 2.6]
b = [2.8, 2.9, 3.0]
print(stats.ttest_ind(a, b))
# Out:
# Ttest_indResult(statistic=-4.89897948556635, pvalue=0.008049893100837754)

# %%
import statsmodels.api as sm

x = [1, 2, 3, 4]
y = [2, 4, 6, 8]
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.146e+30
# Date:                Wed, 21 May 2025   Prob (F-statistic):           1.63e-31
# Time:                        21:10:56   Log-Likelihood:                 131.51
# No. Observations:                   4   AIC:                            -259.0
# Df Residuals:                       2   BIC:                            -260.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.441e-16   2.21e-15      0.201      0.859   -9.06e-15    9.95e-15
# ...

# %%
import plotly.express as px

data = {'x': [1, 2, 3], 'y': [2, 4, 6]}
fig = px.line(data, x='x', y='y', title='Doğrusal Grafik')
fig.show()

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input

model = Sequential([
    Input(shape=(1,)),
    Dense(1)
])
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
import torch
import torch.nn as nn

model = nn.Linear(1, 1)
x = torch.tensor([[1.0]])
print(model(x))
# Out:
# tensor([[-0.4509]], grad_fn=<AddmmBackward0>)

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('resim.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
import spacy

nlp = spacy.blank("tr")
doc = nlp("Bugün harika bir gün!")

for token in doc:
    print(token.text)
# Out:
# Bugün
# harika
# bir
# gün
# !

# %%
import nltk
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')

text = "Bugün hava çok güzel; dışarı çıkıp yürüyüş yapmalıyım."
tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['Bugün', 'hava', 'çok', 'güzel', 'dışarı', 'çıkıp', 'yürüyüş', 'yapmalıyım']

# %%
from sqlalchemy import create_engine, text

engine = create_engine('sqlite:///veri.db')
conn = engine.connect()

result = conn.execute(text("SELECT * FROM kullanicilar"))
for row in result:
    print(row)
# Out:
# (1, 'İrem', 'irem@example.com')
# (2, 'Ahmet', 'ahmet@example.com')

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://example.com'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
print(soup.title.text)
# Out:
# Example Domain
